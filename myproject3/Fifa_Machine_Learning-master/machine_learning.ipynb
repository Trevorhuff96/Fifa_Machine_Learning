# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, ShuffleSplit, GridSearchCV


import os
import time
import sys

from sklearn.externals import joblib

# %%
df = pd.read_csv("million1.csv")

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1               Name  Age  Overall  Potential  \
# 0              0             0  Cristiano Ronaldo   32       94         94
# 1              1             1           L. Messi   30       93         93
# 2              3             3          L. Suárez   30       92         92
# 3              2             2             Neymar   25       92         94
# 4              5             5     R. Lewandowski   28       91         91
# 5              7             7          E. Hazard   26       90         91
# 6              9             9         G. Higuaín   29       90         90
# 7              8             8           T. Kroos   27       90         90
# 8             10            10       Sergio Ramos   31       90         90
# 9             17            17       G. Chiellini   32       89         89
# 10            11            11       K. De Bruyne   26       89         92
# 11            15            15            G. Bale   27       89         89
# 12            14            14          L. Modrić   31       89         89
# 13            13            13         A. Sánchez   28       89         89
# 14            16            16          S. Agüero   29       89         89
# 15            19            19          P. Dybala   23       88         93
# 16            21            21       A. Griezmann   26       88         91
# 17            22            22             Thiago   26       88         90
# 18            23            23      P. Aubameyang   28       88         88
# 19            31            31     Z. Ibrahimović   35       88         88
# 20            25            25         J. Boateng   28       88         88
# 21            26            26           D. Godín   31       88         88
# 22            27            27         M. Hummels   28       88         88
# 23            24            24         L. Bonucci   30       88         88
# 24            30            30       Thiago Silva   32       88         88
# 25            32            32          A. Robben   33       88         88
# 26            28            28            M. Özil   28       88         88
# 27            33            33           N. Kanté   26       87         90
# 28            34            34        M. Verratti   24       87         91
# 29            35            35           P. Pogba   24       87         92
# ...          ...           ...                ...  ...      ...        ...
# 6322       10146         10146       Nacho Méndez   19       65         80
# 6323       10125         10125    E. Palmer-Brown   20       65         82
# 6324       10120         10120         R. Sweeney   20       65         79
# 6325       10116         10116      S. Colombatto   20       65         79
# 6326       10071         10071        F. Del Sole   19       65         84
# 6327       10054         10054         D. Valoyes   20       65         80
# 6328       10033         10033        S. Alakouch   18       65         82
# 6329       10032         10032   D. Calvert-Lewin   20       65         79
# 6330       10003         10003         J. Makengo   19       65         81
# 6331        9936          9936       Carles Pérez   19       65         78
# 6332       10392         10392            M. Lowe   20       65         79
# 6333       10413         10413         J. Onguéné   19       65         80
# 6334       10440         10440           B. Jatta   19       65         78
# 6335       10852         10852  A. Maitland-Niles   19       65         78
# 6336       10851         10851     G. Castrovilli   20       65         79
# 6337       10838         10838          D. Burnić   19       65         79
# 6338       10814         10814        Y. Nakasaka   19       65         79
# 6339       10726         10726        B. Woodburn   17       65         85
# 6340       10684         10684          Isi Gómez   21       65         78
# 6341       10648         10648          Z. Bytyqi   20       65         79
# 6342       10509         10509          A. Picchi   19       65         78
# 6343       10502         10502          M. Clarke   20       65         82
# 6344       10457         10457         P. Cutrone   19       65         80
# 6345       10456         10456     J. Torunarigha   19       65         80
# 6346       11212         11212   R. Zhemaletdinov   20       64         79
# 6347       11199         11199             F. Ayé   20       64         78
# 6348       11114         11114         M. Benítez   21       64         78
# 6349       11732         11732         J. Hesketh   21       64         78
# 6350       11031         11031           D. Agyei   20       64         78
# 6351       11733         11733   T. Zhamaletdinov   20       64         78
#
#                         Club   Value   Wage  Acceleration     ...       \
# 0             Real Madrid CF  €95.5M  €565K          89.0     ...
# 1               FC Barcelona   €105M  €565K          92.0     ...
# 2               FC Barcelona    €97M  €510K          88.0     ...
# 3        Paris Saint-Germain   €123M  €280K          94.0     ...
# 4           FC Bayern Munich    €92M  €355K          79.0     ...
# 5                    Chelsea  €90.5M  €295K          93.0     ...
# 6                   Juventus    €77M  €275K          78.0     ...
# 7             Real Madrid CF    €79M  €340K          60.0     ...
# 8             Real Madrid CF    €52M  €310K          75.0     ...
# 9                   Juventus    €38M  €225K          68.0     ...
# 10           Manchester City    €83M  €285K          76.0     ...
# 11            Real Madrid CF  €69.5M  €370K          93.0     ...
# 12            Real Madrid CF    €57M  €340K          75.0     ...
# 13                   Arsenal  €67.5M  €265K          88.0     ...
# 14           Manchester City  €66.5M  €325K          90.0     ...
# 15                  Juventus    €79M  €215K          88.0     ...
# 16           Atlético Madrid    €75M  €150K          87.0     ...
# 17          FC Bayern Munich  €70.5M  €225K          77.0     ...
# 18         Borussia Dortmund    €61M  €165K          95.0     ...
# 19         Manchester United    €27M  €240K          63.0     ...
# 20          FC Bayern Munich    €48M  €215K          72.0     ...
# 21           Atlético Madrid    €40M  €125K          62.0     ...
# 22          FC Bayern Munich    €48M  €215K          62.0     ...
# 23                     Milan    €44M  €210K          62.0     ...
# 24       Paris Saint-Germain    €34M  €175K          70.0     ...
# 25          FC Bayern Munich    €36M  €225K          87.0     ...
# 26                   Arsenal    €60M  €265K          75.0     ...
# 27                   Chelsea  €52.5M  €190K          82.0     ...
# 28       Paris Saint-Germain  €64.5M  €130K          69.0     ...
# 29         Manchester United  €66.5M  €195K          72.0     ...
# ...                      ...     ...    ...           ...     ...
# 6322  Real Sporting de Gijón   €1.1M    €2K          67.0     ...
# 6323    Sporting Kansas City   €1.1M    €2K          71.0     ...
# 6324          Bristol Rovers   €1.1M   €11K          53.0     ...
# 6325                 Perugia   €1.2M   €10K          69.0     ...
# 6326                 Pescara   €1.2M    €1K          67.0     ...
# 6327              La Equidad   €1.2M    €1K          77.0     ...
# 6328         Nîmes Olympique     €1M    €1K          74.0     ...
# 6329                 Everton   €1.2M   €20K          79.0     ...
# 6330                OGC Nice   €1.1M    €5K          65.0     ...
# 6331          FC Barcelona B     €1M    €2K          81.0     ...
# 6332            Derby County   €1.1M   €10K          69.0     ...
# 6333    FC Red Bull Salzburg     €1M    €3K          63.0     ...
# 6334            Hamburger SV     €1M    €6K          79.0     ...
# 6335                 Arsenal     €1M   €13K          77.0     ...
# 6336               Cremonese   €1.2M   €12K          73.0     ...
# 6337           VfB Stuttgart     €1M    €6K          76.0     ...
# 6338             Vissel Kobe   €1.2M    €2K          79.0     ...
# 6339               Liverpool   €1.1M   €15K          82.0     ...
# 6340              Granada CF     €1M    €3K          66.0     ...
# 6341               Viking FK   €1.2M    €1K          79.0     ...
# 6342                  Empoli     €1M    €1K          68.0     ...
# 6343              Portsmouth   €1.1M    €3K          54.0     ...
# 6344                   Milan   €1.2M   €14K          65.0     ...
# 6345       Hertha BSC Berlin     €1M    €4K          69.0     ...
# 6346             Rubin Kazan     €1M    €9K          77.0     ...
# 6347              AJ Auxerre     €1M    €2K          76.0     ...
# 6348             Guadalajara     €1M   €12K          78.0     ...
# 6349             Southampton     €1M   €15K          66.0     ...
# 6350                 Walsall     €1M   €12K          77.0     ...
# 6351             CSKA Moscow     €1M   €10K          76.0     ...
#
#       Strength  Sprint speed  Stamina  Preferred Positions  Thou/Mill  \
# 0         80.0          91.0     92.0               ST LW        Mill
# 1         59.0          87.0     73.0                  RW        Mill
# 2         80.0          77.0     89.0                  ST        Mill
# 3         53.0          90.0     78.0                  LW        Mill
# 4         84.0          83.0     79.0                  ST        Mill
# 5         65.0          87.0     79.0                  LW        Mill
# 6         85.0          80.0     72.0                  ST        Mill
# 7         74.0          52.0     77.0              CDM CM        Mill
# 8         81.0          77.0     84.0                  CB        Mill
# 9         91.0          78.0     68.0                  CB        Mill
# 10        73.0          75.0     87.0           RM CM CAM        Mill
# 11        80.0          95.0     76.0                  RW        Mill
# 12        58.0          71.0     82.0              CDM CM        Mill
# 13        72.0          84.0     85.0         RM LW ST LM        Mill
# 14        74.0          84.0     74.0                  ST        Mill
# 15        65.0          84.0     83.0              ST CAM        Mill
# 16        61.0          86.0     76.0            LW RW ST        Mill
# 17        59.0          68.0     75.0          CDM CAM CM        Mill
# 18        77.0          96.0     79.0                  ST        Mill
# 19        88.0          67.0     71.0                  ST        Mill
# 20        91.0          78.0     74.0                  CB        Mill
# 21        80.0          67.0     67.0                  CB        Mill
# 22        85.0          65.0     66.0                  CB        Mill
# 23        85.0          72.0     73.0                  CB        Mill
# 24        81.0          74.0     74.0                  CB        Mill
# 25        67.0          86.0     68.0               RW RM        Mill
# 26        57.0          68.0     69.0              RW CAM        Mill
# 27        77.0          80.0     94.0              CM CDM        Mill
# 28        56.0          62.0     77.0              CDM CM        Mill
# 29        91.0          76.0     91.0              CDM CM        Mill
# ...        ...           ...      ...                  ...        ...
# 6322      50.0          63.0     57.0                  CM        Mill
# 6323      67.0          72.0     56.0                  CB        Mill
# 6324      83.0          55.0     67.0                  CB        Mill
# 6325      54.0          64.0     36.0                  CM        Mill
# 6326      27.0          70.0     53.0                  RW        Mill
# 6327      65.0          80.0     72.0            LM RW RM        Mill
# 6328      52.0          74.0     72.0                  RB        Mill
# 6329      62.0          81.0     69.0               LM ST        Mill
# 6330      57.0          63.0     65.0              CAM CM        Mill
# 6331      57.0          79.0     55.0               LW RW        Mill
# 6332      64.0          69.0     61.0               LM LB        Mill
# 6333      81.0          55.0     68.0                  CB        Mill
# 6334      64.0          79.0     49.0               LW RW        Mill
# 6335      68.0          72.0     72.0               CM RM        Mill
# 6336      30.0          67.0     34.0              CM CAM        Mill
# 6337      62.0          74.0     66.0           LB CB CDM        Mill
# 6338      55.0          78.0     74.0            CM RM RW        Mill
# 6339      56.0          73.0     64.0           CAM ST LW        Mill
# 6340      47.0          50.0     66.0              CAM CM        Mill
# 6341      62.0          76.0     64.0               LM RM        Mill
# 6342      60.0          68.0     60.0                  CM        Mill
# 6343      85.0          61.0     71.0                  CB        Mill
# 6344      69.0          69.0     55.0                  ST        Mill
# 6345      76.0          75.0     52.0               LB CB        Mill
# 6346      65.0          82.0     67.0            RM ST LM        Mill
# 6347      74.0          75.0     63.0               RM ST        Mill
# 6348      41.0          75.0     72.0               ST LW        Mill
# 6349      45.0          65.0     55.0                 CAM        Mill
# 6350      78.0          79.0     68.0                  ST        Mill
# 6351      65.0          73.0     64.0                  ST        Mill
#
#         Value Int  Wage Int  Preferred Position        age group  class group
# 0      95000000.0  565000.0                  ST            30-36  World Class
# 1     105000000.0  565000.0                  RW            24-30  World Class
# 2      97000000.0  510000.0                  ST            24-30  World Class
# 3     123000000.0  280000.0                  LW            24-30  World Class
# 4      92000000.0  355000.0                  ST            24-30  World Class
# 5      90000000.0  295000.0                  LW            24-30  World Class
# 6      77000000.0  275000.0                  ST            24-30  World Class
# 7      79000000.0  340000.0                  CD            24-30  World Class
# 8      52000000.0  310000.0                  CB            30-36  World Class
# 9      38000000.0  225000.0                  CB            30-36  World Class
# 10     83000000.0  285000.0                  RM            24-30  World Class
# 11     69000000.0  370000.0                  RW            24-30  World Class
# 12     57000000.0  340000.0                  CD            30-36  World Class
# 13     67000000.0  265000.0                  RM            24-30  World Class
# 14     66000000.0  325000.0                  ST            24-30  World Class
# 15     79000000.0  215000.0                  ST            18-24  World Class
# 16     75000000.0  150000.0                  LW            24-30  World Class
# 17     70000000.0  225000.0                  CD            24-30  World Class
# 18     61000000.0  165000.0                  ST            24-30  World Class
# 19     27000000.0  240000.0                  ST            30-36  World Class
# 20     48000000.0  215000.0                  CB            24-30  World Class
# 21     40000000.0  125000.0                  CB            30-36  World Class
# 22     48000000.0  215000.0                  CB            24-30  World Class
# 23     44000000.0  210000.0                  CB            24-30  World Class
# 24     34000000.0  175000.0                  CB            30-36  World Class
# 25     36000000.0  225000.0                  RW            30-36  World Class
# 26     60000000.0  265000.0                  RW            24-30  World Class
# 27     52000000.0  190000.0                  CM            24-30  World Class
# 28     64000000.0  130000.0                  CD            18-24  World Class
# 29     66000000.0  195000.0                  CD            18-24  World Class
# ...           ...       ...                 ...              ...          ...
# 6322    1000000.0    2000.0                  CM            18-24     Semi-Pro
# 6323    1000000.0    2000.0                  CB            18-24     Semi-Pro
# 6324    1000000.0   11000.0                  CB            18-24     Semi-Pro
# 6325    1000000.0   10000.0                  CM            18-24     Semi-Pro
# 6326    1000000.0    1000.0                  RW            18-24     Semi-Pro
# 6327    1000000.0    1000.0                  LM            18-24     Semi-Pro
# 6328    1000000.0    1000.0                  RB  Younger than 18     Semi-Pro
# 6329    1000000.0   20000.0                  LM            18-24     Semi-Pro
# 6330    1000000.0    5000.0                  CA            18-24     Semi-Pro
# 6331    1000000.0    2000.0                  LW            18-24     Semi-Pro
# 6332    1000000.0   10000.0                  LM            18-24     Semi-Pro
# 6333    1000000.0    3000.0                  CB            18-24     Semi-Pro
# 6334    1000000.0    6000.0                  LW            18-24     Semi-Pro
# 6335    1000000.0   13000.0                  CM            18-24     Semi-Pro
# 6336    1000000.0   12000.0                  CM            18-24     Semi-Pro
# 6337    1000000.0    6000.0                  LB            18-24     Semi-Pro
# 6338    1000000.0    2000.0                  CM            18-24     Semi-Pro
# 6339    1000000.0   15000.0                  CA  Younger than 18     Semi-Pro
# 6340    1000000.0    3000.0                  CA            18-24     Semi-Pro
# 6341    1000000.0    1000.0                  LM            18-24     Semi-Pro
# 6342    1000000.0    1000.0                  CM            18-24     Semi-Pro
# 6343    1000000.0    3000.0                  CB            18-24     Semi-Pro
# 6344    1000000.0   14000.0                  ST            18-24     Semi-Pro
# 6345    1000000.0    4000.0                  LB            18-24     Semi-Pro
# 6346    1000000.0    9000.0                  RM            18-24     Semi-Pro
# 6347    1000000.0    2000.0                  RM            18-24     Semi-Pro
# 6348    1000000.0   12000.0                  ST            18-24     Semi-Pro
# 6349    1000000.0   15000.0                  CA            18-24     Semi-Pro
# 6350    1000000.0   12000.0                  ST            18-24     Semi-Pro
# 6351    1000000.0   10000.0                  ST            18-24     Semi-Pro
#
# [6352 rows x 25 columns]

# %%
del df["Unnamed: 0"]

# %%
del df["Unnamed: 0.1"]

# %%
# del df

# %%
del df["Name"]
del df["Thou/Mill"]
del df["Preferred Positions"]
del df["age group"]
del df["class group"]
del df["Club"]
del df["Value"]
del df["Wage"]

# %%
del df["Overall"]

# %%
df.count()
# Out:
# Age                   6352
# Potential             6352
# Acceleration          6352
# Aggression            6352
# Ball control          6352
# Dribbling             6352
# Finishing             6352
# Shot power            6352
# Strength              6352
# Sprint speed          6352
# Stamina               6352
# Value Int             6352
# Wage Int              6352
# Preferred Position    6352
# dtype: int64

# %%
df.describe()
# Out:
#                Age    Potential  Acceleration   Aggression  Ball control  \
# count  6352.000000  6352.000000   6352.000000  6352.000000   6352.000000
# mean     25.976228    76.113508     70.573992    64.719301     70.015743
# std       3.830683     4.582510     12.211264    14.061332      7.814859
# min      17.000000    68.000000     26.000000    22.000000     29.000000
# 25%      23.000000    73.000000     65.000000    56.000000     66.000000
# 50%      26.000000    75.000000     72.000000    67.000000     71.000000
# 75%      29.000000    79.000000     79.000000    75.000000     75.000000
# max      38.000000    94.000000     96.000000    96.000000     95.000000
#
#          Dribbling    Finishing   Shot power     Strength  Sprint speed  \
# count  6352.000000  6352.000000  6352.000000  6352.000000   6352.000000
# mean     66.960485    56.015586    67.106895    68.861304     71.044238
# std      11.550094    16.360379    11.483371    12.054466     11.599321
# min      14.000000    10.000000    13.000000    25.000000     27.000000
# 25%      63.000000    44.000000    61.000000    62.000000     65.000000
# 50%      69.000000    60.000000    69.000000    70.000000     72.500000
# 75%      74.000000    69.000000    75.000000    77.000000     78.000000
# max      97.000000    95.000000    94.000000    96.000000     96.000000
#
#            Stamina     Value Int       Wage Int
# count  6352.000000  6.352000e+03    6352.000000
# mean     71.908533  5.264169e+06   25105.006297
# std       9.841092  7.712565e+06   33360.894670
# min      30.000000  1.000000e+06    1000.000000
# 25%      66.000000  1.000000e+06    8000.000000
# 50%      72.000000  3.000000e+06   15000.000000
# 75%      78.000000  6.000000e+06   29000.000000
# max      95.000000  1.230000e+08  565000.000000

# %%
sample_df=df.sample(n=1000)

# %%
sample_df.columns
# Out:
# Index(['Age', 'Potential', 'Acceleration', 'Aggression', 'Ball control',
#        'Dribbling', 'Finishing', 'Shot power', 'Strength', 'Sprint speed',
#        'Stamina', 'Value Int', 'Wage Int', 'Preferred Position'],
#       dtype='object')

# %%
num_cols = ['Age', 'Potential', 'Acceleration', 'Aggression',
       'Ball control', 'Dribbling', 'Finishing', 'Shot power', 'Strength',
       'Sprint speed', 'Stamina', 'Value Int', 'Wage Int']
cat_cols = [
    "Preferred Position"
]

# %%
for col in num_cols:
    sns.kdeplot(sample_df[col])
    plt.show()

# %%
sample_df.dtypes
# Out:
# Age                     int64
# Potential               int64
# Acceleration          float64
# Aggression            float64
# Ball control          float64
# Dribbling             float64
# Finishing             float64
# Shot power            float64
# Strength              float64
# Sprint speed          float64
# Stamina               float64
# Value Int             float64
# Wage Int              float64
# Preferred Position     object
# dtype: object

# %%
sample_df["Preferred Position"].unique()
# Out:
# array(['CB', 'CM', 'ST', 'LB', 'CD', 'RM', 'CA', 'LM', 'CF', 'LW', 'RB',
#        'RW'], dtype=object)

# %%
# omit Value Int from this model since it is directly related to Wage
features_to_use= ['Age', 'Potential', 'Acceleration', 'Aggression',
       'Ball control', 'Dribbling', 'Finishing', 'Shot power', 'Strength',
       'Sprint speed', 'Stamina',
       'Preferred Position']

# %%
X = sample_df[features_to_use]

# %%
y = sample_df[["Wage Int"]]

# %%
X.head()
# Out:
#       Age  Potential  Acceleration  Aggression  Ball control  Dribbling  \
# 3765   28         73          65.0        71.0          64.0       55.0
# 1082   19         86          79.0        90.0          77.0       78.0
# 5718   24         74          74.0        50.0          70.0       73.0
# 5803   22         77          76.0        55.0          63.0       72.0
# 1390   27         77          57.0        80.0          77.0       71.0
#
#       Finishing  Shot power  Strength  Sprint speed  Stamina  \
# 3765       37.0        69.0      84.0          74.0     84.0
# 1082       65.0        85.0      77.0          78.0     86.0
# 5718       66.0        65.0      65.0          78.0     63.0
# 5803       62.0        74.0      40.0          80.0     66.0
# 1390       78.0        80.0      86.0          59.0     79.0
#
#      Preferred Position
# 3765                 CB
# 1082                 CM
# 5718                 ST
# 5803                 ST
# 1390                 ST

# %%
y.head()
# Out:
#       Wage Int
# 3765   10000.0
# 1082   49000.0
# 5718    5000.0
# 5803    7000.0
# 1390   63000.0

# %%
X_encoded = pd.get_dummies(X)

# %%
X_encoded.count()
# Out:
# Age                      1000
# Potential                1000
# Acceleration             1000
# Aggression               1000
# Ball control             1000
# Dribbling                1000
# Finishing                1000
# Shot power               1000
# Strength                 1000
# Sprint speed             1000
# Stamina                  1000
# Preferred Position_CA    1000
# Preferred Position_CB    1000
# Preferred Position_CD    1000
# Preferred Position_CF    1000
# Preferred Position_CM    1000
# Preferred Position_LB    1000
# Preferred Position_LM    1000
# Preferred Position_LW    1000
# Preferred Position_RB    1000
# Preferred Position_RM    1000
# Preferred Position_RW    1000
# Preferred Position_ST    1000
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((750, 23), (250, 23))

# %%
X_train.head()
# Out:
#       Age  Potential  Acceleration  Aggression  Ball control  Dribbling  \
# 3461   26         73          54.0        74.0          65.0       57.0
# 4571   24         76          78.0        69.0          73.0       78.0
# 4993   28         69          66.0        45.0          69.0       65.0
# 1790   32         75          40.0        69.0          62.0       48.0
# 5315   20         75          59.0        59.0          68.0       61.0
#
#       Finishing  Shot power  Strength  Sprint speed          ...            \
# 3461       39.0        59.0      83.0          55.0          ...
# 4571       62.0        79.0      40.0          79.0          ...
# 4993       65.0        67.0      57.0          69.0          ...
# 1790       32.0        72.0      77.0          54.0          ...
# 5315       72.0        65.0      42.0          59.0          ...
#
#       Preferred Position_CD  Preferred Position_CF  Preferred Position_CM  \
# 3461                      0                      0                      1
# 4571                      0                      0                      1
# 4993                      0                      0                      0
# 1790                      0                      0                      0
# 5315                      0                      0                      1
#
#       Preferred Position_LB  Preferred Position_LM  Preferred Position_LW  \
# 3461                      0                      0                      0
# 4571                      0                      0                      0
# 4993                      0                      0                      0
# 1790                      0                      0                      0
# 5315                      0                      0                      0
#
#       Preferred Position_RB  Preferred Position_RM  Preferred Position_RW  \
# 3461                      0                      0                      0
# 4571                      0                      0                      0
# 4993                      0                      1                      0
# 1790                      0                      0                      0
# 5315                      0                      0                      0
#
#       Preferred Position_ST
# 3461                      0
# 4571                      0
# 4993                      0
# 1790                      0
# 5315                      0
#
# [5 rows x 23 columns]

# %%
# normalize
sds = StandardScaler()
sds.fit(X_train)
X_train = sds.transform(X_train)
X_test = sds.transform(X_test)

# %%
joblib.dump(sds, "scaler.model")
# Out:
# ['scaler.model']

# %%
# y_train

# %%
for i in range(5):
    
    t0 = time.time()
    model = DecisionTreeRegressor()
    
    model.fit(X_train, y_train)
    t1 = time.time()
    
#     ypred = model.predict(X_train)
    scores = model.score(X_test, y_test.values.ravel())
    
    print(f"Decision tree {i+1} took {t1-t0} seconds to train and got a score of {scores}")
    print()
    print("And here are the top features: ")
    c = X_encoded.columns 
    for cfi in zip(c, model.feature_importances_):
        print(cfi)
    print()
# Out:
# Decision tree 1 took 0.10611915588378906 seconds to train and got a score of 0.28456031030247875
#
# And here are the top features:
# ('Age', 0.12518465500663759)
# ('Potential', 0.20726782624158738)
# ('Acceleration', 0.055715718851884435)
# ('Aggression', 0.02015273157263686)
# ('Ball control', 0.338769955125401)
# ('Dribbling', 0.02245786087695687)
# ('Finishing', 0.03595539923827276)
# ('Shot power', 0.02699892283229124)
# ('Strength', 0.07119798877205961)
# ('Sprint speed', 0.020138863830409033)
# ('Stamina', 0.036724544530570676)
# ('Preferred Position_CA', 0.002513955926239889)
# ('Preferred Position_CB', 0.0003317914659168867)
# ('Preferred Position_CD', 0.005784513055616516)
# ('Preferred Position_CF', 0.0003305541344092145)
# ('Preferred Position_CM', 0.0007995913957780003)
# ('Preferred Position_LB', 0.0029399370532197646)
# ('Preferred Position_LM', 0.0005278107972629782)
# ('Preferred Position_LW', 0.00041212096615227643)
# ('Preferred Position_RB', 0.0003303587749532812)
# ('Preferred Position_RM', 0.024398927601177067)
# ('Preferred Position_RW', 0.00019749962524926029)
# ('Preferred Position_ST', 0.0008684723253176589)
#
# Decision tree 2 took 0.008433818817138672 seconds to train and got a score of 0.3316326801149273
#
# And here are the top features:
# ('Age', 0.1240025678056513)
# ('Potential', 0.20784207538149035)
# ('Acceleration', 0.025272361885123842)
# ('Aggression', 0.020583660590948055)
# ('Ball control', 0.33828776238312)
# ('Dribbling', 0.022154466201423608)
# ('Finishing', 0.035255967682825885)
# ('Shot power', 0.05898377874999609)
# ('Strength', 0.07816992264262584)
# ('Sprint speed', 0.02350884751811276)
# ('Stamina', 0.025856977573634254)
# ('Preferred Position_CA', 0.002929278215648778)
# ('Preferred Position_CB', 0.00011935797820953006)
# ('Preferred Position_CD', 0.005360605912571503)
# ('Preferred Position_CF', 0.00033055413440921444)
# ('Preferred Position_CM', 0.00010315374937975909)
# ('Preferred Position_LB', 0.002600293297769337)
# ('Preferred Position_LM', 0.00031211670253499484)
# ('Preferred Position_LW', 0.0011573178797750212)
# ('Preferred Position_RB', 0.0005190985183107681)
# ('Preferred Position_RM', 0.02437871183764919)
# ('Preferred Position_RW', 5.335538761022039e-06)
# ('Preferred Position_ST', 0.0022657878200289384)
#
# Decision tree 3 took 0.007735013961791992 seconds to train and got a score of 0.36348104461617126
#
# And here are the top features:
# ('Age', 0.12770990904150165)
# ('Potential', 0.20479612802991656)
# ('Acceleration', 0.022737128416651146)
# ('Aggression', 0.019755749139080344)
# ('Ball control', 0.33730635589887875)
# ('Dribbling', 0.022748052416684327)
# ('Finishing', 0.04139435397321965)
# ('Shot power', 0.08499818421797672)
# ('Strength', 0.06879947072098802)
# ('Sprint speed', 0.02156191507028857)
# ('Stamina', 0.03242411112466478)
# ('Preferred Position_CA', 0.0025674891651421426)
# ('Preferred Position_CB', 0.0010232970506000155)
# ('Preferred Position_CD', 0.005654653382067827)
# ('Preferred Position_CF', 0.0004540619760995396)
# ('Preferred Position_CM', 0.0006642973771949391)
# ('Preferred Position_LB', 0.0025422083832079886)
# ('Preferred Position_LM', 0.0003919521714036206)
# ('Preferred Position_LW', 0.00013338846902555097)
# ('Preferred Position_RB', 0.00030697556460537316)
# ('Preferred Position_RM', 0.0006604635319858833)
# ('Preferred Position_RW', 1.0275852428635273e-05)
# ('Preferred Position_ST', 0.0013595790263877304)
#
# Decision tree 4 took 0.007767200469970703 seconds to train and got a score of 0.30015239281898975
#
# And here are the top features:
# ('Age', 0.12606501890220612)
# ('Potential', 0.20833896789562417)
# ('Acceleration', 0.054384803178707475)
# ('Aggression', 0.015863171120289146)
# ('Ball control', 0.3569057550719404)
# ('Dribbling', 0.0057285810240872955)
# ('Finishing', 0.04019368456956552)
# ('Shot power', 0.03444137326102804)
# ('Strength', 0.07102356695594968)
# ('Sprint speed', 0.020705933739946884)
# ('Stamina', 0.02538894778346469)
# ('Preferred Position_CA', 0.0025411671739211)
# ('Preferred Position_CB', 0.0002332223276206744)
# ('Preferred Position_CD', 0.00536406413213883)
# ('Preferred Position_CF', 0.00033055413440921433)
# ('Preferred Position_CM', 0.0002766575653863241)
# ('Preferred Position_LB', 0.0026749908404236442)
# ('Preferred Position_LM', 0.00029729576153215563)
# ('Preferred Position_LW', 0.0030931468550047265)
# ('Preferred Position_RB', 0.0002843150515711275)
# ('Preferred Position_RM', 0.0243835138225341)
# ('Preferred Position_RW', 5.3355387610220376e-06)
# ('Preferred Position_ST', 0.0014759332938873524)
#
# Decision tree 5 took 0.007654905319213867 seconds to train and got a score of 0.34294897855475925
#
# And here are the top features:
# ('Age', 0.12538621133516697)
# ('Potential', 0.20424486785247298)
# ('Acceleration', 0.05438234290250102)
# ('Aggression', 0.02510734533104031)
# ('Ball control', 0.3345228427463242)
# ('Dribbling', 0.025176714601145997)
# ('Finishing', 0.03546190607253974)
# ('Shot power', 0.029899028164907564)
# ('Strength', 0.06933747652546386)
# ('Sprint speed', 0.019940851358052906)
# ('Stamina', 0.02457528704818562)
# ('Preferred Position_CA', 0.002804643982442237)
# ('Preferred Position_CB', 0.0010311422687041849)
# ('Preferred Position_CD', 0.015065456887503829)
# ('Preferred Position_CF', 0.0014273037686193001)
# ('Preferred Position_CM', 0.0004932044342581679)
# ('Preferred Position_LB', 0.002938738203769755)
# ('Preferred Position_LM', 0.00048690500009514236)
# ('Preferred Position_LW', 0.002836151738015499)
# ('Preferred Position_RB', 0.00012731188321438662)
# ('Preferred Position_RM', 0.024392702805955863)
# ('Preferred Position_RW', 8.53968505401673e-05)
# ('Preferred Position_ST', 0.0002761682390802016)

# %%
plt.scatter(model.predict(X_train), y_train.values)

# %% [markdown]
# ## get ride of overall

# %%
#dribble.com
